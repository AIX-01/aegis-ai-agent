# %%
# !pip install Pillow matplotlib

# %%
import base64                                                                                               
import matplotlib.pyplot as plt                                                                             
from PIL import Image                                                                                       
from io import BytesIO                                                                                      
                                                                                                          
base64_list = [
  "...",
  "...",
  "...",
  "...",
  "...",
  "...",
  "...",
  "..."
]

fig, axes = plt.subplots(2, 4, figsize=(16, 8))

for i, base64_string in enumerate(base64_list):
  row, col = divmod(i, 4)
  img = Image.open(BytesIO(base64.b64decode(base64_string)))
  axes[row][col].imshow(img)
  axes[row][col].set_title(f"Frame {i+1}")
  axes[row][col].axis("off")

plt.tight_layout()
plt.show()

# abnormal/assault
# 실내 휴게 공간에서 2~3명의 인원이 마스크를 착용한 채로 평온하게 움직이고 있습니다. 기물 파손, 쓰러짐, 폭행 등 비정상적 행동이나 위협적 상황은 관찰되지 않습니다.
# https://smith.langchain.com/public/0aa39cb8-d7fa-4cc0-93ff-051326525afd/r

# %%
base64_list = [
  "...",
  "...",
  "...",
  "...",
  "...",
  "...",
  "...",
  "..."
]

fig, axes = plt.subplots(2, 4, figsize=(16, 8))

for i, base64_string in enumerate(base64_list):
  row, col = divmod(i, 4)
  img = Image.open(BytesIO(base64.b64decode(base64_string)))
  axes[row][col].imshow(img)
  axes[row][col].set_title(f"Frame {i+1}")
  axes[row][col].axis("off")

plt.tight_layout()
plt.show()

# abnormal/burglary
# 실내 공간에서 한 사람이 마스크를 착용한 채 천천히 걷고 있습니다. 주변에 이상 행동이나 위협적인 상황은 발견되지 않았습니다.
# https://smith.langchain.com/public/cc209b7a-504f-4f11-a683-e79ff932d51f/r

# %%
base64_list = [
  "...",
  "...",
  "...",
  "...",
  "...",
  "...",
  "...",
  "..."
]

fig, axes = plt.subplots(2, 4, figsize=(16, 8))

for i, base64_string in enumerate(base64_list):
  row, col = divmod(i, 4)
  img = Image.open(BytesIO(base64.b64decode(base64_string)))
  axes[row][col].imshow(img)
  axes[row][col].set_title(f"Frame {i+1}")
  axes[row][col].axis("off")

plt.tight_layout()
plt.show()

# abnormal/swoon/A person is lying motionless on the floor in a library after collapsing.
# abnormal/swoon/도서관 바닥에 한 사람이 쓰러져 움직이지 않고 누워 있는 상황입니다. 주변에 타인이나 물리적 충돌 흔적이 없어 의료적 응급상황으로 판단됩니다.
# https://smith.langchain.com/public/40fab8c2-d0d5-4dc6-be96-a1bc1d9369c2/r

# %%
base64_list = [
  "...",
  "...",
  "...",
  "...",
  "...",
  "...",
  "...",
  "..."
]

fig, axes = plt.subplots(2, 4, figsize=(16, 8))

for i, base64_string in enumerate(base64_list):
  row, col = divmod(i, 4)
  img = Image.open(BytesIO(base64.b64decode(base64_string)))
  axes[row][col].imshow(img)
  axes[row][col].set_title(f"Frame {i+1}")
  axes[row][col].axis("off")

plt.tight_layout()
plt.show()

# abnormal/assault/A group of people are engaging in a physical altercation on a city street at night, with several individuals involved in violent actions.
# 보행자들과 자전거 이용자들이 인도에서 정상적으로 이동하고 있으며, 특별한 위협이나 이상 행동은 관찰되지 않습니다. 주변 상점 및 도로도 평온한 상태로 보입니다.
# https://smith.langchain.com/public/4437ed9b-6aa9-4c56-9a87-ddc2f92f240d/r

# %%
base64_list = [
  "...",
  "...",
  "...",
  "...",
  "...",
  "...",
  "...",
  "..."
]

fig, axes = plt.subplots(2, 4, figsize=(16, 8))

for i, base64_string in enumerate(base64_list):
  row, col = divmod(i, 4)
  img = Image.open(BytesIO(base64.b64decode(base64_string)))
  axes[row][col].imshow(img)
  axes[row][col].set_title(f"Frame {i+1}")
  axes[row][col].axis("off")

plt.tight_layout()
plt.show()
